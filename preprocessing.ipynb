# %%
# Out:
# ...
# 100%|██████████| 107M/107M [00:06<00:00, 16.8MB/s]
# Extracting files...
# Path to dataset files: C:\Users\lisa-\.cache\kagglehub\datasets\preetviradiya\brian-tumor-dataset\versions\1
